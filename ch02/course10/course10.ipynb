# %%
import sys
import sqlite3
import os

# 添加上一層目錄到 sys.path
sys.path.insert(0, os.path.join(os.getcwd(), '..'))

from finlab.crawler import (
    widget,
    crawl_price,
    crawl_monthly_report,
    crawl_finance_statement_by_date,
    date_range,
    month_range,
    season_range,
)

# 創建 data 目錄（如果不存在）
os.makedirs(os.path.join('..', 'data'), exist_ok=True)

conn = sqlite3.connect(os.path.join('..', 'data', "data.db"))

widget(conn, 'price', crawl_price, date_range)
widget(conn, 'monthly_revenue', crawl_monthly_report, month_range)
widget(conn, 'finance_statement', crawl_finance_statement_by_date, season_range)
# Out:
# VBox(children=(Label(value='price (from 2018-03-26 to 2018-08-13)'), HBox(children=(DatePicker(value=datetime.…
# VBox(children=(Label(value='monthly_revenue (No table found)(對於finance_statement是正常情況)'), HBox(children=(DateP…
# VBox(children=(Label(value='finance_statement (No table found)(對於finance_statement是正常情況)'), HBox(children=(Dat…
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# # 時間區間範例：

# %%
import datetime

print('2010年抓取財報的時間點是')
season_range(datetime.date(2016, 1, 1), datetime.date(2018, 1, 1))
# Out:
# 2010年抓取財報的時間點是
# [datetime.date(2016, 3, 31),
#  datetime.date(2016, 5, 15),
#  datetime.date(2016, 8, 14),
#  datetime.date(2016, 11, 14),
#  datetime.date(2017, 3, 31),
#  datetime.date(2017, 5, 15),
#  datetime.date(2017, 8, 14),
#  datetime.date(2017, 11, 14)]
# 2010年抓取財報的時間點是
# [datetime.date(2016, 3, 31),
#  datetime.date(2016, 5, 15),
#  datetime.date(2016, 8, 14),
#  datetime.date(2016, 11, 14),
#  datetime.date(2017, 3, 31),
#  datetime.date(2017, 5, 15),
#  datetime.date(2017, 8, 14),
#  datetime.date(2017, 11, 14)]
# 2010年抓取財報的時間點是
# [datetime.date(2016, 3, 31),
#  datetime.date(2016, 5, 15),
#  datetime.date(2016, 8, 14),
#  datetime.date(2016, 11, 14),
#  datetime.date(2017, 3, 31),
#  datetime.date(2017, 5, 15),
#  datetime.date(2017, 8, 14),
#  datetime.date(2017, 11, 14)]

# %% [markdown]
# # 每季財報 時間區間補充：
#
# 關於每季財報爬取，選取的時間範圍要「包含」以下時段，就能夠爬到截止日期的財報囉！例如：
#
# - 2010年3月31號 --> 2009 第四季
# - 2010年5月15號 --> 2010 第一季
# - 2010年8月14號 --> 2010 第二季
# - 2010年11月14號 --> 2010 第三季
#
# 所以假如我們想要抓2018年的第一季，就可以輸入一個時間範圍，例如：
#
# - 2018年5月01號 到 2018年5月31號
#
# 因為這段時間有包含 2018年5月15號，所以就會下載 2018年第一季的財報喔！

# %% [markdown]
# # 程式化更新資料

# %%
import datetime
from finlab.crawler import update_table

update_table(conn, 'price', crawl_price, [datetime.date(2018, 3, 26)])
update_table(conn, 'monthly_revenue', crawl_monthly_report, [datetime.date(2018, 3, 1)])
update_table(
    conn, 'finance_statement', crawl_finance_statement_by_date, [datetime.date(2018, 3, 31)]
)
# Out:
# start crawl price from  2018-03-26 to 2018-03-26
#   0%|          | 0/1 [00:00<?, ?it/s]
# crawling 2018-03-26
# success
# start crawl monthly_revenue from  2018-03-01 to 2018-03-01
#   0%|          | 0/1 [00:00<?, ?it/s]
# crawling 2018-03-01
# https://mops.twse.com.tw/nas/t21/sii/t21sc03_107_3.html
# e:\program-related\Self-learning\hahow-finlab-python-stock-selection\.venv\Lib\site-packages\urllib3\connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# **WARRN: Pandas cannot find any table in the HTML file
# fail, check if it is a holiday
# start crawl finance_statement from  2018-03-31 to 2018-03-31
#   0%|          | 0/1 [00:00<?, ?it/s]
# crawling 2018-03-31
# https://mops.twse.com.tw/nas/t21/sii/t21sc03_106_11.html
# **WARRN: Pandas cannot find any table in the HTML file
# e:\program-related\Self-learning\hahow-finlab-python-stock-selection\.venv\Lib\site-packages\urllib3\connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 6
#       2 from finlab.crawler import update_table
#       3
#       4 update_table(conn, 'price', crawl_price, [datetime.date(2018, 3, 26)])
#       5 update_table(conn, 'monthly_revenue', crawl_monthly_report, [datetime.date(2018, 3, 1)])
# ----> 6 update_table(
#       7     conn, 'finance_statement', crawl_finance_statement_by_date, [datetime.date(2018, 3, 31)]
#       8 )
#
# File e:\program-related\Self-learning\hahow-finlab-python-stock-selection\ch02\course10\..\finlab\crawler.py:823, in update_table(conn, table_name, crawl_function, dates)
#     820 print('crawling', d)
#     821 progress.set_description('crawl' + table_name + str(d))
# --> 823 data = crawl_function(d)
#     825 if data is None:
#     826     print('fail, check if it is a holiday')
#
# File e:\program-related\Self-learning\hahow-finlab-python-stock-selection\ch02\course10\..\finlab\crawler.py:712, in crawl_finance_statement_by_date(date)
#     710 else:
#     711     df = crawl_monthly_report(datetime.datetime(year, month, 1))
# --> 712     crawl_finance_statement(year, season, df.index.levels[0])
#     713 html2db(date)
#     714 return {}
#
# AttributeError: 'NoneType' object has no attribute 'index'
